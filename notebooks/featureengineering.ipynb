# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\avisw\\Desktop\\climate-trend-analysis-ml\\Data\\climate_processed.csv")
# Feature engineering
df["TEMP_RANGE"] = df["T2M_MAX"] - df["T2M_MIN"]
df["TEMP_ANOMALY"] = df["T2M"] - df["T2M"].mean()

df["TEMP_MA7"] = df["T2M"].rolling(7).mean()
df["TEMP_MA30"] = df["T2M"].rolling(30).mean()

df["RAIN_MA7"] = df["PRECTOTCORR"].rolling(7).mean()

df["HEATWAVE"] = (df["T2M_MAX"] >= 40).astype(int)
df["EXTREME_RAIN"] = (df["PRECTOTCORR"] > 50).astype(int)

df = df.dropna()

# %%
df.head()
# Out:
#       T2M  T2M_MAX  T2M_MIN   RH2M  WS10M  PRECTOTCORR        DATE  YEAR  \
# 29  17.57    25.56     9.91  52.72   2.82         0.00  2000-01-30  2000
# 30  18.72    26.47    11.38  49.07   1.63         0.00  2000-01-31  2000
# 31  19.44    28.00    12.55  57.41   2.58         0.00  2000-02-01  2000
# 32  21.16    28.40    15.45  75.70   4.02         4.26  2000-02-02  2000
# 33  22.05    28.52    17.14  75.62   2.31         4.78  2000-02-03  2000
#
#     MONTH  HEAVY_RAIN  HEATWAVE  EXTREME_RAIN  TEMP_ANOMALY  TEMP_MA30  \
# 29      1       False         0             0     -8.278686  17.609667
# 30      1       False         0             0     -7.128686  17.699333
# 31      2       False         0             0     -6.408686  17.818667
# 32      2       False         0             0     -4.688686  18.014000
# 33      2       False         0             0     -3.798686  18.236667
#
#     TEMP_RANGE   TEMP_MA7  RAIN_MA7
# 29       15.65  18.638571  0.058571
# 30       15.09  18.547143  0.058571
# 31       15.45  18.704286  0.058571
# 32       12.95  19.150000  0.667143
# 33       11.38  19.611429  1.350000

# %%
df.to_csv("../Data/climate_features.csv", index=False)

print("Feature engineering complete")
# Out:
# Feature engineering complete
